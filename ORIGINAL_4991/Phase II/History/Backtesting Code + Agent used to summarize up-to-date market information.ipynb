# %% [markdown]
# # Backtesting code

# %%
# !pip install backtrader
# Out:
# Collecting backtrader
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123

# %%
from datetime import datetime
import backtrader as bt
import yfinance as yf
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')

# Define your strategy
class AlphaFactorStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.02),  # Example buy threshold
        ('sell_threshold', -0.01), # Example sell threshold
    )

    def __init__(self):
        self.alpha_factor = {}

    def next(self):
        for data in self.datas:
            ticker = data._name
            current_date = self.data.datetime.date(0)
            alpha_value = alpha_dict.get((current_date, ticker), None)

            if alpha_value is not None:
                if alpha_value > self.p.buy_threshold and not self.getposition(data).size > 0:
                    self.buy(data)
                elif alpha_value < self.p.sell_threshold and not self.getposition(data).size < 0:
                    self.sell(data)

# Create a cerebro instance
cerebro = bt.Cerebro()

# Load your alpha factor dataset
alpha_data = pd.read_csv('hang_seng_index_stocks_with_factors.csv', parse_dates=['Date'])

# Identify all potential alpha factor columns
excluded_columns = ['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume']
alpha_factor_columns = [col for col in alpha_data.columns if col not in excluded_columns]

# Iterate through each alpha factor column and run a backtest
for alpha_factor_column in alpha_factor_columns:
    print(f"\n--- Backtest for Alpha Factor: {alpha_factor_column} ---")

    # Create a new cerebro instance for each alpha factor
    cerebro = bt.Cerebro()

    # Create a dictionary to store alpha factors indexed by date and ticker for the current alpha factor
    alpha_dict = {}
    for index, row in alpha_data.iterrows():
        date = row['Date'].date()
        ticker = row['Ticker']
        alpha_value = row[alpha_factor_column]
        alpha_dict[(date, ticker)] = alpha_value

    # Add data for each stock
    tickers = alpha_data['Ticker'].unique()
    for ticker in tickers:
        ticker_data = alpha_data[alpha_data['Ticker'] == ticker]

        data = bt.feeds.PandasData(
            dataname=ticker_data,
            datetime='Date',
            close='Close',
            open='Open',
            high='High',
            low='Low',
            volume='Volume'
        )
        cerebro.adddata(data, name=ticker)

    # Add the strategy with the defined thresholds
    cerebro.addstrategy(AlphaFactorStrategy, buy_threshold=0.02, sell_threshold=-0.01) # You can adjust these thresholds

    # Add the analyzers
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='annual_return')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trade_analyzer') # Optional: For more detailed trade analysis

    # Set initial cash
    cerebro.broker.setcash(100000)

    # Run the backtest
    results = cerebro.run()

    # Print the final portfolio value
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Print the analysis results
    if results and results[0].analyzers:
        print('\n--- Backtest Performance ---')
        # Annual Return
        annual_return = results[0].analyzers.annual_return.get_analysis()
        print('\nAnnual Returns:')
        for year, ret in annual_return.items():
            print(f'Year: {year}, Return: {ret:.4f}')

        # Sharpe Ratio
        sharpe_ratio = results[0].analyzers.sharpe_ratio.get_analysis()
        print(f'\nSharpe Ratio: {sharpe_ratio["sharperatio"]:.4f}')

        # Max Drawdown
        drawdown = results[0].analyzers.drawdown.get_analysis()
        print(f'\nMaximum Drawdown:')
        print(f'  Max: {drawdown["max"]["drawdown"]:.2f}%')
        print(f'  Duration: {drawdown["max"]["len"]} days')

        # Optional: Print trade analysis
        trade_analysis = results[0].analyzers.trade_analyzer.get_analysis()
        if trade_analysis['total']['total'] > 0:
            print('\n--- Trade Analysis ---')
            print(f"Total Trades: {trade_analysis['total']['total']}")
            print(f"Winning Trades: {trade_analysis['won']['total']}" if 'won' in trade_analysis else "0")
            print(f"Losing Trades: {trade_analysis['lost']['total']}" if 'lost' in trade_analysis else "0")

            won_pnl_net_total = trade_analysis.get('won', {}).get('pnl', {}).get('net', {}).get('total', 0)
            total_pnl_net_total = trade_analysis.get('total', {}).get('pnl', {}).get('net', {}).get('total', 0)

            if total_pnl_net_total != 0:
                win_rate = (won_pnl_net_total / total_pnl_net_total) * 100
                print(f"Win Rate: {win_rate:.2f}%")
            else:
                print("Win Rate: N/A")

            print(f"Average Profit: {trade_analysis.get('won', {}).get('pnl', {}).get('net', {}).get('average', 0):.2f}")
            print(f"Average Loss: {trade_analysis.get('lost', {}).get('pnl', {}).get('net', {}).get('average', 0):.2f}")
# Out:
# --- Backtest for Alpha Factor: Price_Momentum ---
# Final Portfolio Value: 99292.04
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0066
# Year: 2022, Return: 0.0034
# Year: 2023, Return: -0.0066
# Year: 2024, Return: 0.0017
# Year: 2025, Return: 0.0010
#
# Sharpe Ratio: -2.8137
#
# Maximum Drawdown:
#   Max: 1.52%
#   Duration: 741 days
#
# --- Trade Analysis ---
# Total Trades: 5780
# Winning Trades: 2334
# Losing Trades: 3372
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Volume_Momentum ---
# Final Portfolio Value: 100356.09
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0020
# Year: 2022, Return: 0.0049
# Year: 2023, Return: -0.0041
# Year: 2024, Return: -0.0006
# Year: 2025, Return: 0.0053
#
# Sharpe Ratio: -2.7232
#
# Maximum Drawdown:
#   Max: 1.31%
#   Duration: 648 days
#
# --- Trade Analysis ---
# Total Trades: 13696
# Winning Trades: 6783
# Losing Trades: 6842
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Rate_of_Change_Momentum ---
# Final Portfolio Value: 99186.83
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0010
# Year: 2022, Return: -0.0013
# Year: 2023, Return: -0.0127
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0012
#
# Sharpe Ratio: -2.0246
#
# Maximum Drawdown:
#   Max: 2.23%
#   Duration: 879 days
#
# --- Trade Analysis ---
# Total Trades: 17595
# Winning Trades: 8209
# Losing Trades: 9342
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Mean_Reversion_20 ---
# Final Portfolio Value: 100324.57
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: 0.0061
# Year: 2022, Return: -0.0026
# Year: 2023, Return: 0.0035
# Year: 2024, Return: -0.0019
# Year: 2025, Return: -0.0018
#
# Sharpe Ratio: -2.9556
#
# Maximum Drawdown:
#   Max: 1.49%
#   Duration: 630 days
#
# --- Trade Analysis ---
# Total Trades: 5749
# Winning Trades: 3485
# Losing Trades: 2192
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Z_score_Mean_Reversion ---
# Final Portfolio Value: 99709.69
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0062
# Year: 2022, Return: 0.0028
# Year: 2023, Return: -0.0031
# Year: 2024, Return: 0.0016
# Year: 2025, Return: 0.0019
#
# Sharpe Ratio: -3.2953
#
# Maximum Drawdown:
#   Max: 1.43%
#   Duration: 765 days
#
# --- Trade Analysis ---
# Total Trades: 5918
# Winning Trades: 2290
# Losing Trades: 3556
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Momentum_Index ---
# Final Portfolio Value: 99186.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0010
# Year: 2022, Return: -0.0013
# Year: 2023, Return: -0.0127
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0012
#
# Sharpe Ratio: -2.0244
#
# Maximum Drawdown:
#   Max: 2.23%
#   Duration: 879 days
#
# --- Trade Analysis ---
# Total Trades: 18266
# Winning Trades: 8565
# Losing Trades: 9656
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Rate_of_Change ---
# Final Portfolio Value: 100422.16
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0017
# Year: 2022, Return: 0.0042
# Year: 2023, Return: -0.0025
# Year: 2024, Return: 0.0053
# Year: 2025, Return: -0.0011
#
# Sharpe Ratio: -3.1186
#
# Maximum Drawdown:
#   Max: 0.93%
#   Duration: 495 days
#
# --- Trade Analysis ---
# Total Trades: 7512
# Winning Trades: 3322
# Losing Trades: 4130
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Standard_Deviation ---
# Final Portfolio Value: 99232.30
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: TR ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: ATR ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: SMA_20 ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Std_20 ---
# Final Portfolio Value: 99232.30
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Upper_Band ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Lower_Band ---
# Final Portfolio Value: 99217.17
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0037
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9716
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 83
# Winning Trades: 0
# Losing Trades: 1
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Bollinger_Band_Width ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: RSI ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: ROC ---
# Final Portfolio Value: 99186.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0010
# Year: 2022, Return: -0.0013
# Year: 2023, Return: -0.0127
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0012
#
# Sharpe Ratio: -2.0244
#
# Maximum Drawdown:
#   Max: 2.23%
#   Duration: 879 days
#
# --- Trade Analysis ---
# Total Trades: 18266
# Winning Trades: 8565
# Losing Trades: 9656
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: SMA_5 ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Momentum_Index_Volatility ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: MA ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: EMA ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: RSI_Technical ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: BB_Upper ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: BB_Lower ---
# Final Portfolio Value: 99217.17
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0037
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9716
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 83
# Winning Trades: 0
# Losing Trades: 1
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: OBV ---
# Final Portfolio Value: 99220.78
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9746
#
# Maximum Drawdown:
#   Max: 2.76%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 105
# Winning Trades: 2
# Losing Trades: 21
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: EMA_12 ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: EMA_26 ---
# Final Portfolio Value: 99232.37
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0036
# Year: 2022, Return: -0.0095
# Year: 2023, Return: -0.0060
# Year: 2024, Return: 0.0057
# Year: 2025, Return: 0.0058
#
# Sharpe Ratio: -1.9710
#
# Maximum Drawdown:
#   Max: 2.75%
#   Duration: 867 days
#
# --- Trade Analysis ---
# Total Trades: 82
# 0
# 0
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: MACD ---
# Final Portfolio Value: 99339.35
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0082
# Year: 2022, Return: 0.0028
# Year: 2023, Return: -0.0024
# Year: 2024, Return: 0.0004
# Year: 2025, Return: 0.0009
#
# Sharpe Ratio: -3.1479
#
# Maximum Drawdown:
#   Max: 1.19%
#   Duration: 741 days
#
# --- Trade Analysis ---
# Total Trades: 2180
# Winning Trades: 716
# Losing Trades: 1383
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Momentum_Technical ---
# Final Portfolio Value: 99292.04
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0066
# Year: 2022, Return: 0.0034
# Year: 2023, Return: -0.0066
# Year: 2024, Return: 0.0017
# Year: 2025, Return: 0.0010
#
# Sharpe Ratio: -2.8137
#
# Maximum Drawdown:
#   Max: 1.52%
#   Duration: 741 days
#
# --- Trade Analysis ---
# Total Trades: 5780
# Winning Trades: 2334
# Losing Trades: 3372
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Trading_Volume_Normalized ---
# Final Portfolio Value: 100308.99
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0026
# Year: 2022, Return: 0.0048
# Year: 2023, Return: -0.0035
# Year: 2024, Return: -0.0009
# Year: 2025, Return: 0.0053
#
# Sharpe Ratio: -2.7796
#
# Maximum Drawdown:
#   Max: 1.24%
#   Duration: 648 days
#
# --- Trade Analysis ---
# Total Trades: 13343
# Winning Trades: 6620
# Losing Trades: 6653
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00
#
# --- Backtest for Alpha Factor: Volume_Percentage_Change ---
# Final Portfolio Value: 100350.41
#
# --- Backtest Performance ---
#
# Annual Returns:
# Year: 2020, Return: 0.0000
# Year: 2021, Return: -0.0020
# Year: 2022, Return: 0.0049
# Year: 2023, Return: -0.0041
# Year: 2024, Return: -0.0006
# Year: 2025, Return: 0.0053
#
# Sharpe Ratio: -2.7355
#
# Maximum Drawdown:
#   Max: 1.31%
#   Duration: 648 days
#
# --- Trade Analysis ---
# Total Trades: 13695
# Winning Trades: 6783
# Losing Trades: 6841
# Win Rate: N/A
# Average Profit: 0.00
# Average Loss: 0.00

# %%
from datetime import datetime
import backtrader as bt
import yfinance as yf
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')

# Define your strategy with buy and sell thresholds as parameters
class AlphaFactorStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.02),
        ('sell_threshold', -0.01),
    )

    def __init__(self):
        pass  # Removed unused self.alpha_factor

    def next(self):
        for data in self.datas:
            ticker = data._name
            current_date = self.data.datetime.date(0)

            # Access the alpha_dict directly, which was populated from the CSV
            alpha_value = alpha_dict.get((current_date, ticker), None)

            if alpha_value is not None:
                if alpha_value > self.p.buy_threshold and not self.getposition(data).size > 0:
                    self.buy(data)
                elif alpha_value < self.p.sell_threshold and not self.getposition(data).size < 0:
                    self.sell(data)

try:
    # Load your alpha factor dataset
    alpha_data = pd.read_csv('hang_seng_index_stocks_with_factors.csv', parse_dates=['Date'])
except FileNotFoundError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' was not found.")
    exit()
except pd.errors.EmptyDataError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' is empty.")
    exit()
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}")
    exit()

# Identify all potential alpha factor columns
excluded_columns = ['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume']
alpha_factor_columns = [col for col in alpha_data.columns if col not in excluded_columns]

# Iterate through each alpha factor column and run a backtest
for alpha_factor_column in alpha_factor_columns:
    print(f"\n--- Optimization for Alpha Factor: {alpha_factor_column} ---")

    # Create a new cerebro instance for each alpha factor
    cerebro = bt.Cerebro()

    # Create a dictionary to store alpha factors indexed by date and ticker for the current alpha factor
    alpha_dict = {}
    for index, row in alpha_data.iterrows():
        date = row['Date'].date()
        ticker = row['Ticker']
        alpha_value = row[alpha_factor_column]
        alpha_dict[(date, ticker)] = alpha_value

    # Add data for each stock
    tickers = alpha_data['Ticker'].unique()
    for ticker in tickers:
        ticker_data = alpha_data[alpha_data['Ticker'] == ticker]

        data = bt.feeds.PandasData(
            dataname=ticker_data,
            datetime='Date',
            close='Close',
            open='Open',
            high='High',
            low='Low',
            volume='Volume'
        )
        cerebro.adddata(data, name=ticker)

    # Add the strategy for optimization - Use optstrategy instead of addstrategy
    cerebro.optstrategy(AlphaFactorStrategy,
                        buy_threshold=range(1, 5, 1),  # Example range: 0.01, 0.02, 0.03, 0.04
                        sell_threshold=range(-4, 0, 1)) # Example range: -0.04, -0.03, -0.02, -0.01
    
    # Set the commission - Example: 0.1% per trade
    cerebro.broker.setcommission(commission=0.001)

    # Set initial cash
    cerebro.broker.setcash(100000)

    # Add the analyzers
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='annual_return')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio', riskfreerate=0.02)  # Example 2% annual risk-free rate
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trade_analyzer')

    # Run the backtest
    results = cerebro.run()

    # Print the final portfolio value
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Print the analysis results
    if results and results[0].analyzers:
        print('\n--- Backtest Performance ---')
        # Annual Return
        annual_return = results[0].analyzers.annual_return.get_analysis()
        print('\nAnnual Returns:')
        for year, ret in annual_return.items():
            print(f'Year: {year}, Return: {ret:.4f}')

        # Sharpe Ratio
        sharpe_ratio = results[0].analyzers.sharpe_ratio.get_analysis()
        print(f'\nSharpe Ratio: {sharpe_ratio["sharperatio"]:.4f}')

        # Max Drawdown
        drawdown = results[0].analyzers.drawdown.get_analysis()
        print(f'\nMaximum Drawdown:')
        print(f'  Max: {drawdown["max"]["drawdown"]:.2f}%')
        print(f'  Duration: {drawdown["max"]["len"]} days')

        # Trade Analysis
        trade_analysis = results[0].analyzers.trade_analyzer.get_analysis()
        if trade_analysis['total']['total'] > 0:
            print('\n--- Trade Analysis ---')
            print(f"Total Trades: {trade_analysis['total']['total']}")
            print(f"Winning Trades: {trade_analysis.get('won', {}).get('total', 0)}")
            print(f"Losing Trades: {trade_analysis.get('lost', {}).get('total', 0)}")

            won_pnl_net_total = trade_analysis.get('won', {}).get('pnl', {}).get('net', {}).get('total', 0)
            total_pnl_net_total = trade_analysis.get('total', {}).get('pnl', {}).get('net', {}).get('total', 0)

            if total_pnl_net_total != 0:
                win_rate = (won_pnl_net_total / total_pnl_net_total) * 100
                print(f"Win Rate: {win_rate:.2f}%")
            else:
                print("Win Rate: N/A")

            print(f"Average Profit: {trade_analysis.get('won', {}).get('pnl', {}).get('net', {}).get('average', 0):.2f}")
            print(f"Average Loss: {trade_analysis.get('lost', {}).get('pnl', {}).get('net', {}).get('average', 0):.2f}")

    # Plot the results for the last alpha factor tested (optional - can be resource-intensive for many factors)
    if alpha_factor_column == alpha_factor_columns[-1]:
        cerebro.plot()

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')

# Define your strategy with buy and sell thresholds as parameters
class AlphaFactorStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.02),
        ('sell_threshold', -0.01),
    )

    def __init__(self):
        pass

    def next(self):
        for data in self.datas:
            ticker = data._name
            current_date = self.data.datetime.date(0)
            alpha_value = alpha_dict.get((current_date, ticker), None)

            if alpha_value is not None:
                if alpha_value > self.p.buy_threshold and not self.getposition(data).size > 0:
                    self.buy(data)
                elif alpha_value < self.p.sell_threshold and not self.getposition(data).size < 0:
                    self.sell(data)

try:
    # Load your alpha factor dataset
    alpha_data = pd.read_csv('hang_seng_index_stocks_with_factors.csv', parse_dates=['Date'])
except FileNotFoundError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' was not found.")
    exit()
except pd.errors.EmptyDataError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' is empty.")
    exit()
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}")
    exit()

# Identify all potential alpha factor columns
excluded_columns = ['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume']
alpha_factor_columns = [col for col in alpha_data.columns if col not in excluded_columns]

# Define the ranges for optimization
buy_threshold_range = range(1, 5, 1)  # Test values like 0.01, 0.02, 0.03, 0.04
sell_threshold_range = range(-4, 0, 1) # Test values like -0.04, -0.03, -0.02, -0.01

# Iterate through each alpha factor column and run optimization
for alpha_factor_column in alpha_factor_columns:
    print(f"\n--- Optimization for Alpha Factor: {alpha_factor_column} ---")

    # Create a new cerebro instance for each alpha factor
    cerebro = bt.Cerebro()

    # Create a dictionary to store alpha factors indexed by date and ticker for the current alpha factor
    alpha_dict = {}
    for index, row in alpha_data.iterrows():
        date = row['Date'].date()
        ticker = row['Ticker']
        alpha_value = row[alpha_factor_column]
        alpha_dict[(date, ticker)] = alpha_value

    # Add data for each stock
    tickers = alpha_data['Ticker'].unique()
    for ticker in tickers:
        ticker_data = alpha_data[alpha_data['Ticker'] == ticker]

        data = bt.feeds.PandasData(
            dataname=ticker_data,
            datetime='Date',
            close='Close',
            open='Open',
            high='High',
            low='Low',
            volume='Volume'
        )
        cerebro.adddata(data, name=ticker)

    # Add the strategy for optimization
    cerebro.optstrategy(AlphaFactorStrategy,
                        buy_threshold= buy_threshold_range,
                        sell_threshold= sell_threshold_range)

    # Set the commission
    cerebro.broker.setcommission(commission=0.001)

    # Set initial cash
    cerebro.broker.setcash(100000)

    # Add the analyzers
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name='annual_return')
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio', riskfreerate=0.02)
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trade_analyzer')

    # Run the optimization
    optimized_results = cerebro.run(maxcpus=1)

    # Analyze the optimized results to find the best Sharpe Ratio
    best_sharpe_ratio = -float('inf')
    best_annual_return = -float('inf')
    min_max_drawdown = float('inf')
    best_buy_threshold = None
    best_sell_threshold = None
    best_params = False  # Initialize best_params

    for run in optimized_results:
        first_strategy = run[0]
        sharpe_analysis = first_strategy.analyzers.sharpe_ratio.get_analysis()
        sharpe = sharpe_analysis.get('sharperatio')  # Use .get() to handle potential missing key
        annual_ret_analysis = first_strategy.analyzers.annual_return.get_analysis()
        overall_annual_return = list(annual_ret_analysis.values())[-1] if annual_ret_analysis else -float('inf')
        max_drawdown = first_strategy.analyzers.drawdown.get_analysis()['max']['drawdown']

        if sharpe is not None and sharpe > best_sharpe_ratio:
            best_sharpe_ratio = sharpe
            best_annual_return = overall_annual_return
            min_max_drawdown = max_drawdown
            best_buy_threshold = first_strategy.p.buy_threshold / 100.0
            best_sell_threshold = first_strategy.p.sell_threshold / 100.0
            best_params = True  # Set best_params to True when a best result is found
        elif sharpe is not None and sharpe == best_sharpe_ratio:
            # If Sharpe is the same, prefer higher return and lower drawdown
            if overall_annual_return > best_annual_return:
                best_annual_return = overall_annual_return
                min_max_drawdown = max_drawdown
                best_buy_threshold = first_strategy.p.buy_threshold / 100.0
                best_sell_threshold = first_strategy.p.sell_threshold / 100.0
            elif overall_annual_return == best_annual_return and max_drawdown < min_max_drawdown:
                min_max_drawdown = max_drawdown
                best_buy_threshold = first_strategy.p.buy_threshold / 100.0
                best_sell_threshold = first_strategy.p.sell_threshold / 100.0
            best_params = True

    if best_params:
        print("\n--- Best Optimization Results (Based on Sharpe Ratio) ---")
        print(f"Alpha Factor: {alpha_factor_column}")
        print(f"Best Buy Threshold: {best_buy_threshold:.4f}")
        print(f"Best Sell Threshold: {best_sell_threshold:.4f}")
        print(f"Best Sharpe Ratio: {best_sharpe_ratio:.4f}")
        print(f"Corresponding Annual Return: {best_annual_return:.4f}")
        print(f"Corresponding Max Drawdown: {min_max_drawdown:.2f}%")

# You can choose to plot the results of the best run if you want
# if best_params and alpha_factor_column == alpha_factor_columns[-1]:
#     cerebro.plot()
# Out:
# --- Optimization for Alpha Factor: Price_Momentum ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Price_Momentum
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -5.5027
# Corresponding Annual Return: 0.0013
# Corresponding Max Drawdown: 2.24%
#
# --- Optimization for Alpha Factor: Volume_Momentum ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Volume_Momentum
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -5.2746
# Corresponding Annual Return: 0.0046
# Corresponding Max Drawdown: 2.18%
#
# --- Optimization for Alpha Factor: Rate_of_Change_Momentum ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Rate_of_Change_Momentum
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.2896
# Corresponding Annual Return: 0.0028
# Corresponding Max Drawdown: 3.06%
#
# --- Optimization for Alpha Factor: Mean_Reversion_20 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Mean_Reversion_20
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -4.9101
# Corresponding Annual Return: -0.0024
# Corresponding Max Drawdown: 1.33%
#
# --- Optimization for Alpha Factor: Z_score_Mean_Reversion ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Z_score_Mean_Reversion
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -3.4659
# Corresponding Annual Return: -0.0057
# Corresponding Max Drawdown: 1.92%
#
# --- Optimization for Alpha Factor: Momentum_Index ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Momentum_Index
# Best Buy Threshold: 0.0200
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -2.8927
# Corresponding Annual Return: 0.0056
# Corresponding Max Drawdown: 3.12%
#
# --- Optimization for Alpha Factor: Rate_of_Change ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Rate_of_Change
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -48.9214
# Corresponding Annual Return: 0.0001
# Corresponding Max Drawdown: 0.12%
#
# --- Optimization for Alpha Factor: Standard_Deviation ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Standard_Deviation
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7634
# Corresponding Annual Return: 0.0057
# Corresponding Max Drawdown: 2.73%
#
# --- Optimization for Alpha Factor: TR ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: TR
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7499
# Corresponding Annual Return: 0.0057
# Corresponding Max Drawdown: 2.74%
#
# --- Optimization for Alpha Factor: ATR ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: ATR
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7745
# Corresponding Annual Return: 0.0056
# Corresponding Max Drawdown: 2.73%
#
# --- Optimization for Alpha Factor: SMA_20 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: SMA_20
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7185
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: Std_20 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Std_20
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7634
# Corresponding Annual Return: 0.0057
# Corresponding Max Drawdown: 2.73%
#
# --- Optimization for Alpha Factor: Upper_Band ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Upper_Band
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7183
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: Lower_Band ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Lower_Band
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7151
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: Bollinger_Band_Width ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Bollinger_Band_Width
# Best Buy Threshold: 0.0200
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -48.9214
# Corresponding Annual Return: 0.0001
# Corresponding Max Drawdown: 0.12%
#
# --- Optimization for Alpha Factor: RSI ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: RSI
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7194
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: ROC ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: ROC
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -2.9897
# Corresponding Annual Return: 0.0052
# Corresponding Max Drawdown: 3.12%
#
# --- Optimization for Alpha Factor: SMA_5 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: SMA_5
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7189
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: Momentum_Index_Volatility ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Momentum_Index_Volatility
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7175
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.73%
#
# --- Optimization for Alpha Factor: MA ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: MA
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7185
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: EMA ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: EMA
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7185
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: RSI_Technical ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: RSI_Technical
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7194
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: BB_Upper ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: BB_Upper
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7183
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: BB_Lower ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: BB_Lower
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7151
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: OBV ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: OBV
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7229
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.76%
#
# --- Optimization for Alpha Factor: EMA_12 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: EMA_12
# Best Buy Threshold: 0.0300
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7190
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: EMA_26 ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: EMA_26
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7182
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.75%
#
# --- Optimization for Alpha Factor: MACD ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: MACD
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -5.0344
# Corresponding Annual Return: -0.0040
# Corresponding Max Drawdown: 1.64%
#
# --- Optimization for Alpha Factor: Momentum_Technical ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Momentum_Technical
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -5.5027
# Corresponding Annual Return: 0.0013
# Corresponding Max Drawdown: 2.24%
#
# --- Optimization for Alpha Factor: Trading_Volume_Normalized ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Trading_Volume_Normalized
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -3.7172
# Corresponding Annual Return: 0.0058
# Corresponding Max Drawdown: 2.72%
#
# --- Optimization for Alpha Factor: Volume_Percentage_Change ---
#
# --- Best Optimization Results (Based on Sharpe Ratio) ---
# Alpha Factor: Volume_Percentage_Change
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0200
# Best Sharpe Ratio: -5.3074
# Corresponding Annual Return: 0.0048
# Corresponding Max Drawdown: 2.14%

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')

# Define your strategy with buy and sell thresholds as parameters
class AlphaFactorStrategy(bt.Strategy):
    params = (
        ('buy_threshold', 0.02),
        ('sell_threshold', -0.01),
        ('alpha_dict', None),  # Keep alpha_dict in params
    )

    def __init__(self):
        pass

    def next(self):
        for data in self.datas:
            ticker = data._name
            current_date = self.data.datetime.date(0)
            alpha_value = self.p.alpha_dict.get((current_date, ticker), None)

            if alpha_value is not None:
                if alpha_value > self.p.buy_threshold and not self.getposition(data).size > 0:
                    self.buy(data)
                elif alpha_value < self.p.sell_threshold and not self.getposition(data).size < 0:
                    self.sell(data)

try:
    # Load your alpha factor dataset
    alpha_data = pd.read_csv('hang_seng_index_stocks_with_factors.csv', parse_dates=['Date'])
except FileNotFoundError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' was not found.")
    exit()
except pd.errors.EmptyDataError:
    print("Error: The file 'hang_seng_index_stocks_with_factors.csv' is empty.")
    exit()
except Exception as e:
    print(f"An error occurred while loading the CSV file: {e}")
    exit()

# Identify all potential alpha factor columns
excluded_columns = ['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume']
alpha_factor_columns = [col for col in alpha_data.columns if col not in excluded_columns]

# Define the ranges for optimization
buy_threshold_range = range(1, 5, 1)  # Test values like 0.01, 0.02, 0.03, 0.04
sell_threshold_range = range(-4, 0, 1) # Test values like -0.04, -0.03, -0.02, -0.01

# Split the data into in-sample and out-of-sample sets
split_date = alpha_data['Date'].max() - pd.Timedelta(days=365)  # Use the last year as out-of-sample
in_sample_data = alpha_data[alpha_data['Date'] <= split_date].copy()
out_of_sample_data = alpha_data[alpha_data['Date'] > split_date].copy()

# Dictionary to store the best parameters for each alpha factor
best_parameters = {}

# Iterate through each alpha factor column and run optimization (in-sample)
for alpha_factor_column in alpha_factor_columns:
    print(f"\n--- In-Sample Optimization for Alpha Factor: {alpha_factor_column} ---")

    # Create a new cerebro instance for each alpha factor
    cerebro_opt = bt.Cerebro()

    # Create a dictionary to store alpha factors indexed by date and ticker for the current alpha factor (in-sample)
    alpha_dict_in_sample = {}
    for index, row in in_sample_data.iterrows():
        date = row['Date'].date()
        ticker = row['Ticker']
        alpha_value = row[alpha_factor_column]
        alpha_dict_in_sample[(date, ticker)] = alpha_value

    # Add data for each stock (in-sample)
    tickers = in_sample_data['Ticker'].unique()
    for ticker in tickers:
        ticker_data_in_sample = in_sample_data[in_sample_data['Ticker'] == ticker].copy()

        data = bt.feeds.PandasData(
            dataname=ticker_data_in_sample,
            datetime='Date',
            close='Close',
            open='Open',
            high='High',
            low='Low',
            volume='Volume'
        )
        cerebro_opt.adddata(data, name=ticker)

    # Add the strategy for optimization
    cerebro_opt.optstrategy(AlphaFactorStrategy,
                            buy_threshold=buy_threshold_range,
                            sell_threshold=sell_threshold_range,
                            alpha_dict=[alpha_dict_in_sample]  # Pass alpha_dict as a single-element list
                            )

    # Set the commission
    cerebro_opt.broker.setcommission(commission=0.001)

    # Set initial cash
    cerebro_opt.broker.setcash(100000)

    # Add the analyzers
    cerebro_opt.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio', riskfreerate=0.02)

    # Run the optimization
    optimized_results = cerebro_opt.run(maxcpus=1)

    # Analyze the optimized results to find the best Sharpe Ratio
    best_sharpe_ratio = -float('inf')
    best_buy_threshold = None
    best_sell_threshold = None

    for run in optimized_results:
        first_strategy = run[0]
        sharpe_analysis = first_strategy.analyzers.sharpe_ratio.get_analysis()
        sharpe = sharpe_analysis.get('sharperatio')

        if sharpe is not None and sharpe > best_sharpe_ratio:
            best_sharpe_ratio = sharpe
            best_buy_threshold = first_strategy.p.buy_threshold / 100.0
            best_sell_threshold = first_strategy.p.sell_threshold / 100.0

    if best_buy_threshold is not None and best_sell_threshold is not None:
        best_parameters[alpha_factor_column] = {
            'buy_threshold': best_buy_threshold,
            'sell_threshold': best_sell_threshold
        }
        print(f"\n--- Best In-Sample Parameters for {alpha_factor_column} ---")
        print(f"Best Buy Threshold: {best_buy_threshold:.4f}")
        print(f"Best Sell Threshold: {best_sell_threshold:.4f}")
        print(f"Best Sharpe Ratio: {best_sharpe_ratio:.4f}")
    else:
        print(f"\n--- No valid best parameters found for {alpha_factor_column} in the in-sample data. ---")

# --- Out-of-Sample Backtesting ---
print("\n--- Out-of-Sample Backtesting ---")
for alpha_factor_column, params in best_parameters.items():
    print(f"\n--- Out-of-Sample Test for Alpha Factor: {alpha_factor_column} ---")

    # Create a new cerebro instance for out-of-sample testing
    cerebro_test = bt.Cerebro()

    # Create a dictionary to store alpha factors indexed by date and ticker for the current alpha factor (out-of-sample)
    alpha_dict_out_of_sample = {}
    for index, row in out_of_sample_data.iterrows():
        date = row['Date'].date()
        ticker = row['Ticker']
        alpha_value = row[alpha_factor_column]
        alpha_dict_out_of_sample[(date, ticker)] = alpha_value

    # Add data for each stock (out-of-sample)
    tickers = out_of_sample_data['Ticker'].unique()
    for ticker in tickers:
        ticker_data_out_of_sample = out_of_sample_data[out_of_sample_data['Ticker'] == ticker].copy()

        data = bt.feeds.PandasData(
            dataname=ticker_data_out_of_sample,
            datetime='Date',
            close='Close',
            open='Open',
            high='High',
            low='Low',
            volume='Volume'
        )
        cerebro_test.adddata(data, name=ticker)

    # Add the strategy with the best parameters
    cerebro_test.addstrategy(AlphaFactorStrategy,
                             buy_threshold=params['buy_threshold'],
                             sell_threshold=params['sell_threshold'],
                             alpha_dict=alpha_dict_out_of_sample) # Pass alpha_dict here

    # Set the commission
    cerebro_test.broker.setcommission(commission=0.001)

    # Set initial cash
    cerebro_test.broker.setcash(100000)

    # Add the analyzers for out-of-sample testing
    cerebro_test.addanalyzer(bt.analyzers.AnnualReturn, _name='annual_return')
    cerebro_test.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe_ratio', riskfreerate=0.02)
    cerebro_test.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro_test.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trade_analyzer')
    cerebro_test.addanalyzer(bt.analyzers.Returns, _name='returns')
    cerebro_test.addanalyzer(bt.analyzers.TimeReturn, _name='time_return')

    # Run the out-of-sample backtest
    print("\n--- Running Out-of-Sample Backtest ---")
    results_test = cerebro_test.run()

    # Analyze and print out-of-sample results
    if results_test:
        first_strategy_test = results_test[0]
        print("\n--- Out-of-Sample Performance ---")
        print(f"Alpha Factor: {alpha_factor_column}")
        print(f"Best Buy Threshold (In-Sample): {params['buy_threshold']:.4f}")
        print(f"Best Sell Threshold (In-Sample): {params['sell_threshold']:.4f}")

        # Print analyzers' results
        print("\n--- Analyzers ---")
        annual_return = first_strategy_test.analyzers.annual_return.get_analysis()
        print("Annual Return:", annual_return)

        sharpe_ratio = first_strategy_test.analyzers.sharpe_ratio.get_analysis()
        print("Sharpe Ratio:", sharpe_ratio)

        drawdown = first_strategy_test.analyzers.drawdown.get_analysis()
        print("Drawdown:", drawdown)

        trade_analyzer = first_strategy_test.analyzers.trade_analyzer.get_analysis()
        print("Trade Analyzer:", trade_analyzer)

        returns = first_strategy_test.analyzers.returns.get_analysis()
        print("Returns:", returns)

        time_return = first_strategy_test.analyzers.time_return.get_analysis()
        print("Time Return:", time_return)
# Out:
# --- In-Sample Optimization for Alpha Factor: Price_Momentum ---
#
# --- Best In-Sample Parameters for Price_Momentum ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -6.4383
#
# --- In-Sample Optimization for Alpha Factor: Volume_Momentum ---
#
# --- Best In-Sample Parameters for Volume_Momentum ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -6.8043
#
# --- In-Sample Optimization for Alpha Factor: Rate_of_Change_Momentum ---
#
# --- Best In-Sample Parameters for Rate_of_Change_Momentum ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -5.5065
#
# --- In-Sample Optimization for Alpha Factor: Mean_Reversion_20 ---
#
# --- Best In-Sample Parameters for Mean_Reversion_20 ---
# Best Buy Threshold: 0.0300
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -5.3998
#
# --- In-Sample Optimization for Alpha Factor: Z_score_Mean_Reversion ---
#
# --- Best In-Sample Parameters for Z_score_Mean_Reversion ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -4.5756
#
# --- In-Sample Optimization for Alpha Factor: Momentum_Index ---
#
# --- Best In-Sample Parameters for Momentum_Index ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -4.6259
#
# --- In-Sample Optimization for Alpha Factor: Rate_of_Change ---
#
# --- Best In-Sample Parameters for Rate_of_Change ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -50.4231
#
# --- In-Sample Optimization for Alpha Factor: Standard_Deviation ---
#
# --- Best In-Sample Parameters for Standard_Deviation ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.0805
#
# --- In-Sample Optimization for Alpha Factor: TR ---
#
# --- Best In-Sample Parameters for TR ---
# Best Buy Threshold: 0.0200
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.0127
#
# --- In-Sample Optimization for Alpha Factor: ATR ---
#
# --- Best In-Sample Parameters for ATR ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -6.9059
#
# --- In-Sample Optimization for Alpha Factor: SMA_20 ---
#
# --- Best In-Sample Parameters for SMA_20 ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1289
#
# --- In-Sample Optimization for Alpha Factor: Std_20 ---
#
# --- Best In-Sample Parameters for Std_20 ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.0805
#
# --- In-Sample Optimization for Alpha Factor: Upper_Band ---
#
# --- Best In-Sample Parameters for Upper_Band ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1302
#
# --- In-Sample Optimization for Alpha Factor: Lower_Band ---
#
# --- Best In-Sample Parameters for Lower_Band ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1432
#
# --- In-Sample Optimization for Alpha Factor: Bollinger_Band_Width ---
#
# --- Best In-Sample Parameters for Bollinger_Band_Width ---
# Best Buy Threshold: 0.0200
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -50.4231
#
# --- In-Sample Optimization for Alpha Factor: RSI ---
#
# --- Best In-Sample Parameters for RSI ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1452
#
# --- In-Sample Optimization for Alpha Factor: ROC ---
#
# --- Best In-Sample Parameters for ROC ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -4.8347
#
# --- In-Sample Optimization for Alpha Factor: SMA_5 ---
#
# --- Best In-Sample Parameters for SMA_5 ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1308
#
# --- In-Sample Optimization for Alpha Factor: Momentum_Index_Volatility ---
#
# --- Best In-Sample Parameters for Momentum_Index_Volatility ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1551
#
# --- In-Sample Optimization for Alpha Factor: MA ---
#
# --- Best In-Sample Parameters for MA ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1289
#
# --- In-Sample Optimization for Alpha Factor: EMA ---
#
# --- Best In-Sample Parameters for EMA ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1284
#
# --- In-Sample Optimization for Alpha Factor: RSI_Technical ---
#
# --- Best In-Sample Parameters for RSI_Technical ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1452
#
# --- In-Sample Optimization for Alpha Factor: BB_Upper ---
#
# --- Best In-Sample Parameters for BB_Upper ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1302
#
# --- In-Sample Optimization for Alpha Factor: BB_Lower ---
#
# --- Best In-Sample Parameters for BB_Lower ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1432
#
# --- In-Sample Optimization for Alpha Factor: OBV ---
#
# --- Best In-Sample Parameters for OBV ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1417
#
# --- In-Sample Optimization for Alpha Factor: EMA_12 ---
#
# --- Best In-Sample Parameters for EMA_12 ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1312
#
# --- In-Sample Optimization for Alpha Factor: EMA_26 ---
#
# --- Best In-Sample Parameters for EMA_26 ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -7.1276
#
# --- In-Sample Optimization for Alpha Factor: MACD ---
#
# --- Best In-Sample Parameters for MACD ---
# Best Buy Threshold: 0.0200
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -5.6516
#
# --- In-Sample Optimization for Alpha Factor: Momentum_Technical ---
#
# --- Best In-Sample Parameters for Momentum_Technical ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0100
# Best Sharpe Ratio: -6.4383
#
# --- In-Sample Optimization for Alpha Factor: Trading_Volume_Normalized ---
#
# --- Best In-Sample Parameters for Trading_Volume_Normalized ---
# Best Buy Threshold: 0.0400
# Best Sell Threshold: -0.0400
# Best Sharpe Ratio: -6.6839
#
# --- In-Sample Optimization for Alpha Factor: Volume_Percentage_Change ---
#
# --- Best In-Sample Parameters for Volume_Percentage_Change ---
# Best Buy Threshold: 0.0100
# Best Sell Threshold: -0.0200
# Best Sharpe Ratio: -7.0027
#
# --- Out-of-Sample Backtesting ---
#
# --- Out-of-Sample Test for Alpha Factor: Price_Momentum ---
#
# --- Running Out-of-Sample Backtest ---
#
# --- Out-of-Sample Performance ---
# Alpha Factor: Price_Momentum
# Best Buy Threshold (In-Sample): 0.0100
# Best Sell Threshold (In-Sample): -0.0100
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, 0.0021936527903376746), (2025, 0.0006666124254339767)])
# Sharpe Ratio: OrderedDict([('sharperatio', -24.321383794311544)])
# Drawdown: AutoOrderedDict([('len', 113), ('drawdown', 0.8344702193896375), ('moneydown', 843.9003428333526), ('max', AutoOrderedDict([('len', 113), ('drawdown', 1.127479179071058), ('moneydown', 1140.220517937094)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 1547), ('open', 74), ('closed', 1473)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 0), ('longest', 18)])), ('lost', AutoOrderedDict([('current', 1), ('longest', 31)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 432.71294764602504), ('average', 0.2937630330251358)])), ('net', AutoOrderedDict([('total', 281.9297374003615), ('average', 0.1913983281740404)]))])), ('won', AutoOrderedDict([('total', 612), ('pnl', AutoOrderedDict([('total', 2134.481923687325), ('average', 3.4877155615805964), ('max', 132.718656590154)]))])), ('lost', AutoOrderedDict([('total', 861), ('pnl', AutoOrderedDict([('total', -1852.552186286967), ('average', -2.151628555501704), ('max', -70.782)]))])), ('long', AutoOrderedDict([('total', 736), ('pnl', AutoOrderedDict([('total', 590.8685751378008), ('average', 0.802810564045925), ('won', AutoOrderedDict([('total', 1500.2703353680809), ('average', 4.871007582363899), ('max', 132.718656590154)])), ('lost', AutoOrderedDict([('total', -909.4017602302798), ('average', -2.124770467827757), ('max', -61.563822104199005)]))])), ('won', 308), ('lost', 428)])), ('short', AutoOrderedDict([('total', 737), ('pnl', AutoOrderedDict([('total', -308.93883773743937), ('average', -0.41918431171972775), ('won', AutoOrderedDict([('total', 634.2115883192469), ('average', 2.0862223299975224), ('max', 40.548884710115765)])), ('lost', AutoOrderedDict([('total', -943.1504260566853), ('average', -2.1781765035951164), ('max', -70.782)]))])), ('won', 304), ('lost', 433)])), ('len', AutoOrderedDict([('total', 16775), ('average', 11.388323150033944), ('max', 76), ('min', 1), ('won', AutoOrderedDict([('total', 9997), ('average', 16.334967320261438), ('max', 76), ('min', 1)])), ('lost', AutoOrderedDict([('total', 6778), ('average', 7.8722415795586524), ('max', 36), ('min', 1)])), ('long', AutoOrderedDict([('total', 8242), ('average', 11.19836956521739), ('max', 71), ('min', 1), ('won', AutoOrderedDict([('total', 5113), ('average', 16.600649350649352), ('max', 71), ('min', 1)])), ('lost', AutoOrderedDict([('total', 3129), ('average', 7.3107476635514015), ('max', 27), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 8533), ('average', 11.578018995929444), ('max', 76), ('min', 1), ('won', AutoOrderedDict([('total', 4884), ('average', 16.06578947368421), ('max', 76), ('min', 1)])), ('lost', AutoOrderedDict([('total', 3649), ('average', 8.427251732101617), ('max', 36), ('min', 1)]))]))]))])
# Returns: OrderedDict([('rtot', 0.0028576405850410146), ('ravg', 1.1711641741971372e-05), ('rnorm', 0.002955693192035446), ('rnorm100', 0.29556931920354457)])
# Time Return: OrderedDict([(datetime.datetime(2024, 3, 24, 0, 0), 0.0), (datetime.datetime(2024, 3, 25, 0, 0), 0.0), (datetime.datetime(2024, 3, 26, 0, 0
, 0), -8.789542097820124e-06), (datetime.datetime(2024, 6, 6, 0, 0), 0.0002770110217196198), (datetime.datetime(2024, 6, 10, 0, 0), 0.0001764086509277174), (datetime.datetime(2024, 6, 11, 0, 0), 0.0003516034381385591), (datetime.datetime(2024, 6, 12, 0, 0), -0.0001375021773379892), (datetime.datetime(2024, 6, 13, 0, 0), 0.00018628422840305525), (datetime.datetime(2024, 6, 16, 0, 0), 0.00011720014907945497), (datetime.datetime(2024, 6, 17, 0, 0), 0.00022064867867110927), (datetime.datetime(2024, 6, 18, 0, 0), -0.000542985372165794), (datetime.datetime(2024, 6, 19, 0, 0), 0.00032151923522527603), (datetime.datetime(2024, 6, 20, 0, 0), 0.00040320454415532225), (datetime.datetime(2024, 6, 23, 0, 0), 7.732639481705661e-05), (datetime.datetime(2024, 6, 24, 0, 0), -2.685868232599198e-06), (datetime.datetime(2024, 6, 25, 0, 0), 3.7891039028625784e-06), (datetime.datetime(2024, 6, 26, 0, 0), 0.00018465110058252243), (datetime.datetim ...
#
# --- Out-of-Sample Test for Alpha Factor: Volume_Momentum ---
#
# --- Running Out-of-Sample Backtest ---
#
# --- Out-of-Sample Performance ---
# Alpha Factor: Volume_Momentum
# Best Buy Threshold (In-Sample): 0.0100
# Best Sell Threshold (In-Sample): -0.0400
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, -0.0027732124022723514), (2025, 0.0045171983499205925)])
# Sharpe Ratio: OrderedDict([('sharperatio', -5.2474428880217)])
# Drawdown: AutoOrderedDict([('len', 113), ('drawdown', 0.4195612275389409), ('moneydown', 422.0584742327337), ('max', AutoOrderedDict([('len', 113), ('drawdown', 0.9160169895259729), ('moneydown', 921.4691625305422)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 3633), ('open', 71), ('closed', 3562)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 1), ('longest', 22)])), ('lost', AutoOrderedDict([('current', 0), ('longest', 35)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 448.3189628706565), ('average', 0.12586158418603496)])), ('net', AutoOrderedDict([('total', 106.1482440485082), ('average', 0.029800180810923133)]))])), ('won', AutoOrderedDict([('total', 1693), ('pnl', AutoOrderedDict([('total', 2911.1342650723423), ('average', 1.719512265252417), ('max', 103.32279998779296)]))])), ('lost', AutoOrderedDict([('total', 1869), ('pnl', AutoOrderedDict([('total', -2804.986021023829), ('average', -1.500795088830299), ('max', -68.15299526330277)]))])), ('long', AutoOrderedDict([('total', 1804), ('pnl', AutoOrderedDict([('total', 427.26902784563134), ('average', 0.23684535911620364), ('won', AutoOrderedDict([('total', 1664.0567637128797), ('average', 1.9833811248067696), ('max', 103.32279998779296)])), ('lost', AutoOrderedDict([('total', -1236.7877358672467), ('average', -1.2816453221422246), ('max', -37.82289686232759)]))])), ('won', 839), ('lost', 965)])), ('short', AutoOrderedDict([('total', 1758), ('pnl', AutoOrderedDict([('total', -321.12078379712295), ('average', -0.18266256188687313), ('won', AutoOrderedDict([('total', 1247.077501359462), ('average', 1.4602781046363724), ('max', 49.22)])), ('lost', AutoOrderedDict([('total', -1568.1982851565842), ('average', -1.7347326163236552), ('max', -68.15299526330277)]))])), ('won', 854), ('lost', 904)])), ('len', AutoOrderedDict([('total', 14794), ('average', 4.153284671532846), ('max', 26), ('min', 1), ('won', AutoOrderedDict([('total',
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, -0.004198727861869256), (2025, -0.0022156922111726818)])
# Sharpe Ratio: OrderedDict([('sharperatio', -23.405741624835713)])
# Drawdown: AutoOrderedDict([('len', 242), ('drawdown', 0.640511698442162), ('moneydown', 640.511698442162), ('max', AutoOrderedDict([('len', 242), ('drawdown', 1.172139702800341), ('moneydown', 1172.1397028003412)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 1439), ('open', 73), ('closed', 1366)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 4), ('longest', 25)])), ('lost', AutoOrderedDict([('current', 0), ('longest', 16)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', -204.5589040205724), ('average', -0.1497502957690867)])), ('net', AutoOrderedDict([('total', -349.19541926632996), ('average', -0.25563354265470717)]))])), ('won', AutoOrderedDict([('total', 800), ('pnl', AutoOrderedDict([('total', 1684.4718897138691), ('average', 2.1055898621423363), ('max', 45.63039389038086)]))])), ('lost', AutoOrderedDict([('total', 566), ('pnl', AutoOrderedDict([('total', -2033.6673089801984), ('average', -3.593051782650527), ('max', -144.513298903999)]))])), ('long', AutoOrderedDict([('total', 700), ('pnl', AutoOrderedDict([('total', 165.89861603354527), ('average', 0.23699802290506466), ('won', AutoOrderedDict([('total', 855.5044847165962), ('average', 2.076467195914068), ('max', 45.63039389038086)])), ('lost', AutoOrderedDict([('total', -689.6058686830515), ('average', -2.3944648218161513), ('max', -33.773957629388065)]))])), ('won', 412), ('lost', 288)])), ('short', AutoOrderedDict([('total', 666), ('pnl', AutoOrderedDict([('total', -515.0940352998755), ('average', -0.7734144674172304), ('won', AutoOrderedDict([('total', 828.967404997274), ('average', 2.1365139304053455), ('max', 42.21459997558594)])), ('lost', AutoOrderedDict([('total', -1344.0614402971482), ('average', -4.834753382363843), ('max', -144.513298903999)]))])), ('won', 388), ('lost', 278)])), ('len', AutoOrderedDict([('total', 16821), ('average', 12.314055636896047), ('max', 82), ('min', 1), ('won', AutoOrderedDict([('total', 6331), ('average', 7.91375), ('max', 33), ('min', 1)])), ('lost', AutoOrderedDict([('total', 10490), ('average', 18.53356890459364), ('max', 82), ('min', 1)])), ('long', AutoOrderedDict([('total', 8950), ('average', 12.785714285714286), ('max', 82), ('min', 1), ('won', AutoOrderedDict([('total', 3558), ('average', 8.635922330097088), ('max', 33), ('min', 1)])), ('lost', AutoOrderedDict([('total', 5392), ('average', 18.72222222222222), ('max', 82), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 7871), ('average', 11.818318318318319), ('max', 74), ('min', 1), ('won', AutoOrderedDict([('total', 2773), ('average', 7.146907216494846), ('max', 24), ('min', 1)])), ('lost', AutoOrderedDict([('total', 5098), ('average', 18.33812949640288), ('max', 74), ('min', 1)]))]))]))])
# Returns: OrderedDict([('rtot', -0.0064257177602473365), ('ravg', -2.633490885347269e-05), ('rnorm', -0.006614424780692386), ('rnorm100', -0.6614424780692386)])
# Time Return: OrderedDict([(datetime.datetime(2024, 3, 24, 0, 0), 0.0), (datetime.datetime(2024, 3, 25, 0, 0), 0.0), (datetime.datetime(2024, 3, 26, 0, 0), -0.00017200623047430863), (datetime.datetime(2024, 3, 27, 0, 0), 2.3251917051769766e-05), (datetime.datetime(2024, 4, 1, 0, 0), -0.00038376457156130694), (datetime.datetime(2024, 4, 2, 0, 0), -7.799303619249187e-05), (datetime.datetime(2024, 4, 4, 0, 0), -0.00013842641581707227), (datetime.datetime(2024, 4, 7, 0, 0), 0.00023666207382078142), (datetime.datetime(2024,
 11, 0, 0), -0.0002722126320492402), (datetime.datetime(2024, 6, 12, 0, 0), -7.49622163976893e-05), (datetime.datetime(2024, 6, 13, 0, 0), -0.00020712185680171746), (datetime.datetime(2024, 6, 16, 0, 0), -0.00017338283713430602), (datetime.datetime(2024, 6, 17, 0, 0), -0.00019881445476488402), (datetime.datetime(2024, 6, 18, 0, 0), 0.0003452161835586498), (datetime.datetime(2024, 6, 19, 0, 0), -0.0002717954687391222), (datetime.datetime(2024, 6, 20, 0, 0), -0.0003670743160533174), (datetime.datetime(2024, 6, 23, 0, 0), -4.540092798954731e-05), (datetime.datetime(2024, 6, 24, 0, 0), 4.115749782318545e-06), (datetime.datetime(2024, 6, 25, 0, 0), 2.0879397006901e-06), (datetime.datetime(2024, 6, 26, 0, 0), -0.0002456025040700194), (date ...
#
# --- Out-of-Sample Test for Alpha Factor: Z_score_Mean_Reversion ---
#
# --- Running Out-of-Sample Backtest ---
#
# --- Out-of-Sample Performance ---
# Alpha Factor: Z_score_Mean_Reversion
# Best Buy Threshold (In-Sample): 0.0400
# Best Sell Threshold (In-Sample): -0.0100
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, 0.001646095453607943), (2025, 0.001541201927964586)])
# Sharpe Ratio: OrderedDict([('sharperatio', -350.953048747665)])
# Drawdown: AutoOrderedDict([('len', 113), ('drawdown', 0.7134170573454649), ('moneydown', 720.8353015755711), ('max', AutoOrderedDict([('len', 113), ('drawdown', 1.0474279813701413), ('moneydown', 1058.319333769483)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 1538), ('open', 72), ('closed', 1466)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 0), ('longest', 13)])), ('lost', AutoOrderedDict([('current', 5), ('longest', 20)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 182.0817232319703), ('average', 0.1242030854242635)])), ('net', AutoOrderedDict([('total', 36.768256878350805), ('average', 0.025080666356310236)]))])), ('won', AutoOrderedDict([('total', 573), ('pnl', AutoOrderedDict([('total', 1896.933112445052), ('average', 3.3105289920507017), ('max', 142.90193469059483)]))])), ('lost', AutoOrderedDict([('total', 893), ('pnl', AutoOrderedDict([('total', -1860.164855566702), ('average', -2.083051350018703), ('max', -47.16959390258789)]))])), ('long', AutoOrderedDict([('total', 710), ('pnl', AutoOrderedDict([('total', 362.0556792508053), ('average', 0.5099375764095849), ('won', AutoOrderedDict([('total', 1273.1685897211962), ('average', 4.5797431284935115), ('max', 142.90193469059483)])), ('lost', AutoOrderedDict([('total', -911.1129104703907), ('average', -2.1090576631259044), ('max', -43.78540002441406)]))])), ('won', 278), ('lost', 432)])), ('short', AutoOrderedDict([('total', 756), ('pnl', AutoOrderedDict([('total', -325.2874223724546), ('average', -0.43027436821753257), ('won', AutoOrderedDict([('total', 623.7645227238555), ('average', 2.1144560092334084), ('max', 32.813854802175)])), ('lost', AutoOrderedDict([('total', -949.0519450963103), ('average', -2.0586810088857055), ('max', -47.16959390258789)]))])), ('won', 295), ('lost', 461)])), ('len', AutoOrderedDict([('total', 16797), ('average', 11.457708049113233), ('max', 77), ('min', 1), ('won', AutoOrderedDict([('total', 10251), ('average', 17.89005235602094), ('max', 77), ('min', 1)])), ('lost', AutoOrderedDict([('total', 6546), ('average', 7.330347144456887), ('max', 33), ('min', 1)])), ('long', AutoOrderedDict([('total', 7926), ('average', 11.163380281690142), ('max', 71), ('min', 1), ('won', AutoOrderedDict([('total', 4950), ('average', 17.805755395683452), ('max', 71), ('min', 1)])), ('lost', AutoOrderedDict([('total', 2976), ('average', 6.888888888888889), ('max', 27), ('min', 1)]))])), ('short', AutoOrderedDict([('total',
oOrderedDict([('total', 2460.1632474980574), ('average', 2.2508355420842245), ('max', 94.57652409014037)])), ('lost', AutoOrderedDict([('total', -1612.954283198), ('average', -1.2976301554288012), ('max', -34.518618316650446)]))])), ('won', 1093), ('lost', 1243)])), ('short', AutoOrderedDict([('total', 2538), ('pnl', AutoOrderedDict([('total', -247.71422513764284), ('average', -0.09760213756408308), ('won', AutoOrderedDict([('total', 1536.140281957849), ('average', 1.249910725759031), ('max', 56.77927688769746)])), ('lost', AutoOrderedDict([('total', -1783.854507095494), ('average', -1.3627612735641665), ('max', -45.29621085764456)]))])), ('won', 1229), ('lost', 1309)])), ('len', AutoOrderedDict([('total', 13150), ('average', 2.6979893311448504), ('max', 18), ('min', 1), ('won', AutoOrderedDict([('total', 7428), ('average', 3.198966408268734), ('max', 18), ('min', 1)])), ('lost', AutoOrderedDict([('total', 5722), ('average', 2.2421630094043885), ('max', 11), ('min', 1)])), ('long', AutoOrderedDict([('total', 6274), ('average', 2.6857876712328768), ('max', 18), ('min', 1), ('won', AutoOrderedDict([('total', 3576), ('average', 3.271729185727356), ('max', 18), ('min', 1)])), ('lost', AutoOrderedDict([('total', 2698), ('average', 2.1705551086082058), ('max', 10), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 6876), ('average', 2.7092198581560285), ('max', 16), ('min', 1), ('won', AutoOrderedDict([('total', 3852), ('average', 3.1342554922701384), ('max', 16), ('min', 1)])), ('lost', AutoOrderedDict([('total', 3024), ('average', 2.3101604278074865), ('max', 11), ('min', 1)]))]))]))])
# Returns: OrderedDict([('rtot', 0.005859454759129695), ('ravg', 2.401415884889219e-05), ('rnorm', 0.006069915759904613), ('rnorm100', 0.6069915759904613)])
# ...
#
# --- Out-of-Sample Test for Alpha Factor: Trading_Volume_Normalized ---
#
# --- Running Out-of-Sample Backtest ---
#
# --- Out-of-Sample Performance ---
# Alpha Factor: Trading_Volume_Normalized
# Best Buy Threshold (In-Sample): 0.0400
# Best Sell Threshold (In-Sample): -0.0400
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, -0.0023986426195300448), (2025, 0.0046965891990897735)])
# Sharpe Ratio: OrderedDict([('sharperatio', -5.313716927683725)])
# Drawdown: AutoOrderedDict([('len', 113), ('drawdown', 0.408516059991554), ('moneydown', 411.1297369644453), ('max', AutoOrderedDict([('len', 113), ('drawdown', 0.9192077223710561), ('moneydown', 925.088793625182)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 3387), ('open', 71), ('closed', 3316)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 0), ('longest', 28)])), ('lost', AutoOrderedDict([('current', 4), ('longest', 36)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 468.25108780497857), ('average', 0.14120961634649534)])), ('net', AutoOrderedDict([('total', 153.18509759876505), ('average', 0.046195747164886926)]))])), ('won', AutoOrderedDict([('total', 1599), ('pnl', AutoOrderedDict([('total', 2815.6366073279246), ('average', 1.7608734254708722), ('max', 103.32279998779296)]))])), ('lost', AutoOrderedDict([('total', 1717), ('pnl', AutoOrderedDict([('total', -2662.451509729158), ('average', -1.550641531583668), ('max', -68.15299526330277)]))])), ('long', AutoOrderedDict([('total', 1696), ('pnl', AutoOrderedDict([('total', 455.7558125890476), ('average', 0.26872394610203276), ('won', AutoOrderedDict([('total', 1649.5984275065362), ('average', 2.0466481730850323), ('max', 103.32279998779296)])), ('lost', AutoOrderedDict([('total', -1193.8426149174875), ('average', -1.3413961965365029), ('max', -37.82289686232759)]
5, 8, 0, 0), 5.00542285568617e-05), (datetime.datetime(2024, 5, 9, 0, 0), 3.434623891229727e-05), (datetime.datetime(2024, 5, 12, 0, 0), -5.766572918408652e-05), (datetime.datetime(2024, 5, 13, 0, 0), 5.771307524193858e-05), (datetime.datetime(2024, 5, 15, 0, 0), 9.101594608651453e-05), (datetime.datetime(2024, 5, 16, 0, 0), 0.00011132082276188449), (datetime.datetime(2024, 5, 19, 0, 0), -1.6020309009268097e-05), (datetime.datetime(2024, 5, 20, 0, 0), -0.0003511982873750652), (datetime.datetime(2024, 5, 21, 0, 0), -0.00017678419568689652), (datetime.datetime(2024, 5, 22, 0, 0), -2.606467680021929e-06), (datetime.datetime(2024, 5, 23, 0, 0), 0.00013436239568931363), (datetime.datetime(2024, 5, 26, 0, 0), -0.0001410120141918103), (datetime.datetime(2024, 5, 27, 0, 0), -3.984870119988493e-05), (datetime.datetime(2024, 5, 28, 0, 0), 7.365083094823532e-05), (datetime.datetime(2024, 5, 29, 0, 0), 0.00012410004525609253), (datetime.datetime(2024, 5, 30, 0, 0), -0.00014894401079268427), (datetime.datetime(2024, 6, 2, 0, 0), 1.4033764941245863e-06), (datetime.datetime(2024, 6, 3, 0, 0), 9.487404749375372e-06), (datetime.datetime(2024, 6, 4, 0, 0), 0.00018662895394205847), (datetime.datetime(2024, 6, 5, 0, 0), 0.000157497568707754), (datetime.datetime(2024, 6, 6, 0, 0), 0.00021601937232373913), (datetime.datetime(2024, 6, 10, 0, 0), 0.00024111745996413525), (datetime.datetime(2024, 6, 11, 0, 0), 0.00025788107313085007), (datetime.datetime(2024, 6, 12, 0, 0), -4.828919048871505e-05), (datetime.datetime(2024, 6, 13, 0, 0), 2.6289098892462448e-05), (datetime.datetime(2024, 6, 16, 0, 0), 1.742639430779569e-05), (datetime.datetime(2024, 6, 17, 0, 0), 0.0002264912691911647), (datetime.datetime(2024, 6, 18, 0, 0), -0.0002740843713682217), (datetime.datetime(2024, 6, 19, 0, 0), 2.986253401515704e-05), (datetime.datetime(2024, 6, 20, 0, 0), 0.00024914225777417087), (datetime.datetime(2024, 6, 23, 0, 0), -3.542193500771784e-05), (datetime.datetime(2024, 6, 24, 0, 0), -6.248142598508366e-05), (datetime.datetime(2024, 6, 25, 0, 0), -0.00011674811584549971), (datetime.datetime(2024, 6, 26, 0, 0), 0.00043094965900514204), (datet ...
#
# --- Out-of-Sample Test for Alpha Factor: Volume_Percentage_Change ---
#
# --- Running Out-of-Sample Backtest ---
#
# --- Out-of-Sample Performance ---
# Alpha Factor: Volume_Percentage_Change
# Best Buy Threshold (In-Sample): 0.0100
# Best Sell Threshold (In-Sample): -0.0200
#
# --- Analyzers ---
# Annual Return: OrderedDict([(2024, -0.002798448827281419), (2025, 0.004517312667770668)])
# Sharpe Ratio: OrderedDict([('sharperatio', -5.232693299993678)])
# Drawdown: AutoOrderedDict([('len', 113), ('drawdown', 0.4195717533797681), ('moneydown', 422.0584742327337), ('max', AutoOrderedDict([('len', 113), ('drawdown', 0.9160399703173184), ('moneydown', 921.4691625305422)]))])
# Trade Analyzer: AutoOrderedDict([('total', AutoOrderedDict([('total', 3633), ('open', 71), ('closed', 3562)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 1), ('longest', 22)])), ('lost', AutoOrderedDict([('current', 0), ('longest', 35)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 445.7927942010591), ('average', 0.12515238467183018)])), ('net', AutoOrderedDict([('total', 103.62460154758028), ('average', 0.029091690496232534)]))])), ('won', AutoOrderedDict([('total', 1692), ('pnl', AutoOrderedDict([('total', 2910.1748575162487), ('average', 1.719961499714095), ('max', 103.32279998779296)]))])), ('lost', AutoOrderedDict([('total', 1870), ('pnl', AutoOrderedDict([('total', -2806.550255968664), ('average', -1.500829013886986), ('max', -68.15299526330277)]))])), ('long', AutoOrderedDict([('total', 1804), ('pnl', AutoOrderedDict([('total', 425.9364032209567), ('average', 0.2361066536701534), ('won', AutoOrderedDict([('total', 1663.1531829054302), ('average', 1.9846696693382222), ('max', 103.32279998779296)])), ('lost', AutoOrderedDict([('total', -1237.216779684472), ('average', -1.2807627118886873), ('max', -37.82289686232759)]))])), ('won', 838), ('lost', 966)])), ('short', AutoOrderedDict([('total', 1758), ('pnl', AutoOrderedDict([('total', -322.3118016733764), ('average', -0.18334004645812083), ('won', AutoOrderedDict([('total', 1247.0216746108179), ('average', 1.4602127337363207), ('max', 49.22)])), ('lost', AutoOrderedDict([('total', -1569.3334762841935), ('average', -1.7359883587214529), ('max', -68.15299526330277)]))])), ('won', 854), ('lost', 904)])), ('len', AutoOrderedDict([('total', 14793), ('average', 4.153003930376193), ('max', 26), ('min', 1), ('won', AutoOrderedDict([('total', 7573), ('average', 4.475768321513002), ('max', 26), ('min', 1)])), ('lost', AutoOrderedDict([('total', 7220), ('average', 3.8609625668449197), ('max', 23), ('min', 1)])), ('long', AutoOrderedDict([('total', 7637), ('average', 4.233370288248337), ('max', 26), ('min', 1), ('won', AutoOrderedDict([('total', 4026), ('average', 4.804295942720763), ('max', 26), ('min', 1)])), ('lost', AutoOrderedDict([('total', 3611), ('average', 3.738095238095238), ('max', 23), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 7156), ('average', 4.070534698521047), ('max', 22), ('min', 1), ('won', AutoOrderedDict([('total', 3547), ('average', 4.153395784543325), ('max', 22), ('min', 1)])), ('lost', AutoOrderedDict([('total', 3609), ('average', 3.9922566371681416), ('max', 20), ('min', 1)]))]))]))])
# Returns: OrderedDict([('rtot', 0.0017047684283595203), ('ravg', 6.98675585393246e-06), ('rnorm', 0.0017622133514230542), ('rnorm100', 0.17622133514230542)])
# Time Return: OrderedDict([(datetime.datetime(2024, 3, 24, 0, 0), 0.0), (datetime.datetime(2024, 3, 25, 0, 0), 0.0), (datetime.datetime(2024, 3, 26, 0, 0), 6.492762805798691e-05), (datetime.datetime(2024, 3, 27, 0, 0), -6.553603161485455e-05), (datetime.datetime(2024, 4, 1, 0, 0), -0.00016102689243968626), (datetime.datetime(2024, 4, 2, 0, 0), -9.684978980240011e-06), (datetime.datetime
05), (datetime.datetime(2024, 6, 6, 0, 0), 0.00021011767853762464), (datetime.datetime(2024, 6, 10, 0, 0), 0.000227648443411832), (datetime.datetime(2024, 6, 11, 0, 0), 0.00024861018942945456), (datetime.datetime(2024, 6, 12, 0, 0), -3.442439900569472e-05), (datetime.datetime(2024, 6, 13, 0, 0), 3.069076221007272e-05), (datetime.datetime(2024, 6, 16, 0, 0), 1.1911559679056438e-05), (datetime.datetime(2024, 6, 17, 0, 0), 0.00020115821296196046), (datetime.datetime(2024, 6, 18, 0, 0), -0.00026561809940006675), (datetime.datetime(2024, 6, 19, 0, 0), 3.464356534110813e-05), (datetime.datetime(2024, 6, 20, 0, 0), 0.00024579364545318505), (datetime.datetime(2024, 6, 23, 0, 0), -4.067017399789208e-05), (datetime.datetime(2024, 6, 24, 0, 0), -6.647969047735014e-05), (datetime.datetime(2024, 6, 25, 0, 0), -0.00012012781922388083), (datetime.datetime(2024, 6, 26, 0, 0), 0.0003164869183243102), (d ...

# %% [markdown]
# # Agent for summarizing up-to-date market information

# %%
import json
import time
import os
from langchain_community.llms import Ollama
from ollama import Client
import pandas as pd
import re
import ast
import numpy as np
from collections import Counter
import yfinance as yf

# Assuming you have a way to set up your Ollama client
client = Client(host='http://localhost:11434')  # Adjust host if needed

def prompt_to_LLM_market_info(hsi_volatility_paths, hsi_index_ticker, max_retries=10):
    """
    Fetches market information from Ollama LLM using HSI Volatility Index and Hang Seng Index data from yfinance.

    Args:
        hsi_volatility_paths (list): List of file paths for the three HSI Volatility Index CSV files.
        hsi_index_ticker (str): Ticker symbol for the Hang Seng Index (e.g., '^HSI').
        max_retries (int): Maximum number of retries for the LLM call.

    Returns:
        str: The summarized market information from the LLM, or None if an error occurs.
    """
    try:
        # Load and combine HSI Volatility Index data
        hsi_volatility_dfs = [pd.read_csv(path) for path in hsi_volatility_paths]
        hsi_volatility_df = pd.concat(hsi_volatility_dfs, ignore_index=True)
        if 'Date' in hsi_volatility_df.columns:
            hsi_volatility_df['Date'] = pd.to_datetime(hsi_volatility_df['Date'])
            hsi_volatility_df = hsi_volatility_df.sort_values(by='Date').drop_duplicates(subset=['Date'], keep='last').reset_index(drop=True)
        else:
            print("Warning: 'Date' column not found in HSI Volatility Index data.")

        # Fetch Hang Seng Index data from yfinance
        start_date = '2020-03-24'
        end_date = '2025-03-24'
        hsi_index_df = yf.download(hsi_index_ticker, start=start_date, end=end_date)
        hsi_index_df = hsi_index_df.reset_index() # Make 'Date' a regular column

        llm = Ollama(model="llama3.2")

        prompt = f"""
        You are a financial analyst providing up-to-date market information for Hong Kong.
        Based on the following data, summarize the recent market trends and potential outlook comprehensively. 
        Provide quantitative and qualitative up-to-date market information with no disclaimers. 

        HSI Volatility Index Data (Recent):
        {hsi_volatility_df.tail(10).to_string()}

        Hang Seng Index Data (from 2020-03-24 to 2025-03-24, recent shown):
        {hsi_index_df.tail(10).to_string()}
        """

        response = llm.invoke(prompt)
        return response

    except Exception as e:
        print(f"Error during market information retrieval: {e}")
        return None

print('Now doing market information')

# --- Define file paths ---
hsi_volatility_file1 = 'HSI Volatility Historical Data_1.csv'  # Replace with your actual file path
hsi_volatility_file2 = 'HSI Volatility Historical Data_2.csv'  # Replace with your actual file path
hsi_volatility_file3 = 'HSI Volatility Historical Data_3.csv'  # Replace with your actual file path
hsi_volatility_paths = [hsi_volatility_file1, hsi_volatility_file2, hsi_volatility_file3]

hang_seng_ticker = '^HSI'  # Ticker symbol for Hang Seng Index

# --- Call the function to get market information ---
market_summary = prompt_to_LLM_market_info(hsi_volatility_paths, hang_seng_ticker)

if market_summary:
    print("\n--- Market Information Summary ---")
    print(market_summary)
else:
    print("\nCould not retrieve market information.")
# Out:
# /var/folders/v3/j0t3d9ws5bzdcq6f1g3c9thr0000gn/T/ipykernel_52544/697806196.py:33: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   hsi_volatility_df['Date'] = pd.to_datetime(hsi_volatility_df['Date'])
# [*********************100%***********************]  1 of 1 completed
# Now doing market information
# --- Market Information Summary ---
# Based on the provided data, here is a comprehensive summary of recent market trends and potential outlook for Hong Kong:
#
# **Hang Seng Index (HSI) Analysis**
#
# The HSI has been experiencing volatility since its last major pullback in March 2023. The index has recovered significantly, reaching new highs in May 2024.
#
# 1. **Recent Trends**: Since its peak on May 2024, the HSI has experienced a gentle correction, with prices ranging between 25,000 and 28,000. The recent volatility data indicates a moderate increase in price swings, suggesting that investors are becoming increasingly cautious.
# 2. **Volatility Index (VIX)**: The VIX index measures market expectation of future volatility. As the VIX has remained relatively stable around 20-25, it suggests that investor sentiment is neutral to slightly bullish, indicating a potential return to growth.
# 3. **Price Levels**: Recent high prices indicate strong demand for HSI stocks, particularly in the mid-to-high end (28,000+). However, prices have started to consolidate, and we can expect more sideways movement before the next major move.
#
# **HSI Volatility Index Data Analysis**
#
# The recent volatility data indicates an increase in price swings since October 2024. This suggests that investors are becoming increasingly cautious, and a correction or consolidation is possible.
#
# | Date       | Price   | Open     | High      | Low       | Vol. Change % |
# |------------|---------|----------|-----------|-----------|----------------|
# | 2025-10-01 | 22.80    | 23.17    | 23.42     | 22.37     | 0.09          |
# | 2025-10-02 | 26.93    | 26.70    | 27.31     | 26.49     | 5.28          |
# | 2025-11-03 | 27.66    | 28.56    | 28.67     | 27.53     | 0.18          |
#
# **Potential Outlook**
#
# Based on the recent market trends and volatility data, here are some potential outlooks for Hong Kong:
#
# 1. **Short-term (Next 3-6 months)**: Expect consolidation or a gentle correction in HSI prices, with the index potentially re-testing previous support levels around 25,000-27,000.
# 2. **Mid-term (Next 6-12 months)**: A potential return to growth is possible if investors regain confidence in the market. We can expect increased demand for HSI stocks, particularly in the mid-to-high end.
# 3. **Long-term**: Hong Kong's economy continues to grow, driven by its strong financial sector and strategic location. The HSI is expected to remain a key benchmark for Asian equities.
#
# **Quantitative Analysis**
#
# To confirm these observations, I would recommend analyzing additional technical indicators, such as:
#
# * Moving averages (50-200 days)
# * Relative Strength Index (RSI)
# * Bollinger Bands
#
# These indicators will provide further insights into the market's trend and potential trading opportunities.
